# %% [markdown]
# ## Machine Learning Operations (MLOps)

# %%
from IPython.core.display import HTML

def load_css():
    styles = open("css/custom.css", "r").read()
    return HTML(f"<style>{styles}</style>")

load_css()
# Out:
# <style>/* custom.css */
# .custom-slide {
#     background-color: #ffffff;
#     padding: 20px;
#     border-radius: 10px;
#     box-shadow: 0 0 10px rgba(0, 0, 0, 0.1);
#     font-family: 'Arial', sans-serif;
#     font-size: 18px;
#     line-height: 1.6;
# }
#
# .custom-slide h1 {
#     color: #333;
#     text-align: left;
#     font-size: 24px;
# }
#
# .custom-slide h2 {
#     color: #333;
#     text-align: left;
#     font-size: 22px;
# }
#
# .custom-slide h3 {
#     color: #333;
#     text-align: left;
#     font-size: 20px;
# }
#
# .custom-slide p, .custom-slide li {
#     color: #666;
#     font-size: 16px;
# }
#
# /* Custom style for quotes */
# .custom-slide blockquote {
#     background-color: #e0e0e0;
#     border-left: 5px solid #007acc;
#     margin: 20px 0;
#     padding: 10px 20px;
#     font-style: italic;
#     color: #555;
# }
#
# .custom-slide blockquote::before {
#     content: "“";
#     font-size: 30px;
#     color: #007acc;
#     margin-right: 10px;
# }
#
# .custom-slide blockquote::after {
#     content: "”";
#     font-size: 30px;
#     color: #007acc;
#     margin-left: 10px;
# }
#
# /* Custom style for information panel */
# .custom-slide .info-panel {
#     background-color: #d9edf7;
#     border: 1px solid #bce8f1;
#     padding: 15px;
#     border-radius: 5px;
#     margin: 20px 0;
#     color: #31708f;
# }
#
# .custom-slide .info-panel h2 {
#     color: #31708f;
#     margin-top: 0;
#     font-size: 18px;
# }
#
# /* Custom style for image references */
# .custom-slide .image-ref {
#     font-size: 12px;
#     font-style: italic;
#     color: #666;
#     margin-top: 5px;
#     display: block;
#     text-align: center;
# }
#
# /* Custom style for AI-generated text stamp */
# .custom-slide .ai-stamp {
#     display: inline-block;
#     padding: 5px 10px;
#     background-color: #ffeb3b;
#     color: #333;
#     font-size: 12px;
#     font-weight: bold;
#     border: 2px solid #333;
#     border-radius: 5px;
#     text-transform: uppercase;
#     margin-top: 10px;
# }
#
# /* Custom style for hands-on time callout */
# .custom-slide .hands-on {
#     background-color: #f5f5f5;
#     border: 2px solid #4caf50;
#     padding: 20px;
#     border-radius: 10px;
#     margin: 20px 0;
#     color: #4caf50;
#     font-size: 20px;
#     text-align: center;
#     font-weight: bold;
#     text-transform: uppercase;
#     box-shadow: 0 4px 8px rgba(0, 0, 0, 0.1);
#     font-family: 'Segoe UI', Tahoma, Geneva, Verdana, sans-serif;
#     position: relative;
#     overflow: hidden;
# }
#
# .custom-slide .hands-on::before {
#     content: " ";
#     position: absolute;
#     width: 150%;
#     height: 150%;
#     top: -75%;
#     left: -75%;
#     background: rgba(255, 255, 255, 0.1);
#     transform: rotate(45deg);
#     transition: all 0.3s ease;
# }
#
# .custom-slide .hands-on:hover::before {
#     top: -100%;
#     left: -100%;
# }
#
# table {
#     width: 100%;
#     border-collapse: collapse;
# }
#
# th, td {
#     border: 1px solid black;
#     padding: 8px;
#     text-align: left;
# }
#
# th {
#     background-color: #323030;
# }
#
# tr:nth-child(even) {
#     background-color: #d6e621;
# }
#
# /* Custom style for code snippets */
# .custom-slide code {
#     background-color: #f5f5f5;
#     padding: 2px 4px;
#     border-radius: 3px;
#     font-family: 'Courier New', Courier, monospace;
#     color: #c7254e;
#     font-size: 16px;
# }
#
# .custom-slide pre {
#     background-color: #f5f5f5;
#     padding: 10px;
#     border-radius: 5px;
#     border: 1px solid #ccc;
#     overflow: auto;
# }
#
# .custom-slide pre code {
#     background-color: transparent;
#     padding: 0;
#     border-radius: 0;
#     font-size: 14px;
#     color: #333;
# }</style>

# %% [markdown]
# ## Importando os pacotes do projeto
# Vamos centralizar nesta célula a importação de todos os pacotes que iremos utilizar neste notebook

# %%
from pathlib import Path
import sys 
import os

current_path = Path(os.getcwd())
parent_path = current_path.parent.absolute()
sys.path.append(str(parent_path))

import json 
import requests
from dotenv import load_dotenv
from mlflow.models import infer_signature
from mlflow import MlflowClient
import mlflow

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# <div class="custom-slide">
#     <div class="hands-on">
#         Continuando nossa implementação
#     </div>
# </div>

# %%
# Carregar variáveis do arquivo .env
load_dotenv()

# Configurar serviço do MLFlow
mlflow.set_tracking_uri(os.getenv('MLFLOW_TRACKING_URI'))

# %% [markdown]
# ## Usando o modelo em modo batch

# %% [markdown]
# Podemos carregar e usar nosso modelo para fazer predições em modo batch, sem a necessidade de um endpoint para inferência.

# %% [markdown]
# Primeiramente, vamos criar uma função para retornar as informações do modelo do MLFlow

# %%
def get_model_uri_by_name_and_alias(model_name, alias):
    
    # Initialize MLflow client
    client = mlflow.tracking.MlflowClient()
    
    # Get the model version details by alias
    model_version_details = client.get_model_version_by_alias(name=model_name, alias=alias)
    
    # Construct the model URI
    model_uri = f"models:/{model_name}/{model_version_details.version}"

    return model_uri, model_version_details.run_id, model_version_details.version

# %% [markdown]
# Podemos recuperar as informações do nosso modelo da seguinte forma

# %%
# Example usage
model_name = 'prod.mlops.kmeans-clustering'
alias = 'champion'
model_uri, run_id, version = get_model_uri_by_name_and_alias(model_name, alias)

# %%
model_uri
# Out:
# 'models:/prod.mlops.kmeans-clustering/8'

# %% [markdown]
# Já com as informações de referência do modelo, podemos carregá-lo

# %%
# Load model as a PyFuncModel.
loaded_model = mlflow.pyfunc.load_model(model_uri)
#logged_model = f"runs:/{run_id}/model"

# Access the underlying custom model
custom_model_instance = loaded_model._model_impl.python_model

# Predict on a Pandas DataFrame.
#import pandas as pd
#loaded_model.predict(pd.DataFrame(data))
# Out:
# Downloading artifacts: 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 7/7 [00:00<00:00, 1893.59it/s]

# %% [markdown]
# E usar o modelo

# %%
data = {
    'method': 'predict',
    'data': [-15.65246980577859, -47.7609277270516]
} 
loaded_model.predict(data)
# Out:
# {'is_region_covered': True,
#  'closest_center': {'id': 4,
#   'distance_in_km': 3.26,
#   'lat': -15.87976388043501,
#   'lng': -47.49671343775075}}

# %%
data = {
    'method': 'get_cluster_centroids',
    'data': None
} 
loaded_model.predict(data)
# Out:
# [{'lat': -15.654655490491816, 'lng': -47.8442808719988, 'cluster': 1},
#  {'lat': -15.623268671816016, 'lng': -47.652359043495856, 'cluster': 2},
#  {'lat': -15.756974903901021, 'lng': -47.771778958240816, 'cluster': 3},
#  {'lat': -15.649905394173633, 'lng': -47.79121659966453, 'cluster': 4},
#  {'lat': -15.879763880435013, 'lng': -47.49671343775075, 'cluster': 5}]

# %%
data = {
    'method': 'get_model_version',
    'data': None
} 
loaded_model.predict(data)
# Out:
# {'version': '8',
#  'run_id': 'dba615b94be34076913fe64c05aff223',
#  'model_uri': 'models:/prod.mlops.kmeans-clustering/8'}

# %% [markdown]
# ## Servindo o modelo via API

# %% [markdown]
# https://mlflow.org/docs/latest/deployment/deploy-model-locally.html
#
# Basta acessar o terminal e digitar
#
# ```
# export MLFLOW_TRACKING_URI=http://localhost:5010
# export AWS_ACCESS_KEY_ID=user
# export AWS_SECRET_ACCESS_KEY=password
# export MLFLOW_S3_ENDPOINT_URL=http://localhost:9000
# mlflow models serve -m "models:/prod.mlops.kmeans-clustering@champion" -p8001  --no-conda
# ```

# %%
payload = json.dumps(
    {
        'inputs': {
            'method': 'get_model_version',
            'data': None
        }
    }
)

response = requests.post(
    url=f"http://localhost:8001/invocations",
    data=payload,
    headers={"Content-Type": "application/json"},
)
print(response.json())
# Out:
# {'predictions': {'version': '3', 'run_id': '481972215b284703ad66af16551aef6a', 'model_uri': 'models:/prod.mlops.kmeans-clustering/3'}}

# %%
payload = json.dumps(
    {
        'inputs': {
            'method': 'get_cluster_centroids',
            'data': None
        }
    }
)

response = requests.post(
    url=f"http://localhost:8001/invocations",
    data=payload,
    headers={"Content-Type": "application/json"},
)
print(response.json())
# Out:
# {'predictions': [{'lat': -15.654655490491816, 'lng': -47.8442808719988, 'cluster': 1}, {'lat': -15.623268671816016, 'lng': -47.652359043495856, 'cluster': 2}, {'lat': -15.756974903901021, 'lng': -47.771778958240816, 'cluster': 3}, {'lat': -15.649905394173633, 'lng': -47.79121659966453, 'cluster': 4}, {'lat': -15.879763880435013, 'lng': -47.49671343775075, 'cluster': 5}]}

# %%
payload = json.dumps(
    {
        'inputs': {
            'method': 'predict',
            'data': [-15.913988770795076, -47.60220527168726]
        }
    }
)

response = requests.post(
    url=f"http://localhost:8001/invocations",
    data=payload,
    headers={"Content-Type": "application/json"},
)
print(response.json())
# Out:
# {'error_code': 'BAD_REQUEST', 'message': 'Encountered an unexpected error while evaluating the model. Verify that the serialized input Dataframe is compatible with the model for inference.', 'stack_trace': 'Traceback (most recent call last):\n  File "/opt/homebrew/anaconda3/envs/mlops-util-env/lib/python3.11/site-packages/mlflow/pyfunc/scoring_server/__init__.py", line 394, in invocations\n    raw_predictions = model.predict(data, params=params)\n                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "/opt/homebrew/anaconda3/envs/mlops-util-env/lib/python3.11/site-packages/mlflow/pyfunc/__init__.py", line 843, in predict\n    return self._predict(data, params)\n           ^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "/opt/homebrew/anaconda3/envs/mlops-util-env/lib/python3.11/site-packages/mlflow/pyfunc/__init__.py", line 893, in _predict\n    return self._predict_fn(data, params=params)\n           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "/opt/homebrew/anaconda3/envs/mlops-util-env/lib/python3.11/site-packages/mlflow/pyfunc/model.py", line 1397, in predict\n    return self.python_model.predict(\n           ^^^^^^^^^^^^^^^^^^^^^^^^^^\n  File "/opt/homebrew/anaconda3/envs/mlops-util-env/lib/python3.11/site-packages/mlflow/pyfunc/utils/data_validation.py", line 77, in wrapper\n    return func(*args, **kwargs)\n           ^^^^^^^^^^^^^^^^^^^^^\n  File "/var/folders/3l/_2d9yn750njgccn9mgpwv1280000gn/T/ipykernel_10543/1038033772.py", line 41, in predict\n  File "/var/folders/3l/_2d9yn750njgccn9mgpwv1280000gn/T/ipykernel_10543/1038033772.py", line 95, in make_predictions\nIndexError: list index out of range\n'}

# %% [markdown]
# <div class="custom-slide">
#     <h1>Conclusão</h1>
#     <p>
#        Parabéns por ter acompanhado o curso até aqui! Realmente fizemos muitas coisas interessantes:
#     </p>
#     <ul>
#         <li>Aulas 1, 2 e 3: Exploramos o problema e criamos um modelo completo de ML</li>
#         <li>Aula 4: Analisamos o erro do modelo e registramos os resultados para futura análise de model drift</li>
#         <li>Aula 5: Aprendemos como utilizar um model registry (MLFlow)</li>
#         <li>Aula 6: Aprendemos como criar um modelo customizado, incorporando algoritmos de ML e regras de negócio. </li>
#         <li>Aula 7: Aprendemos como implementar os pipelines de inferência (batch e online)</li>
#     </ul>
#     <p>
#        Nas próximas aulas, iremos sair um pouco do ambiente do jupyter notebook para realizar as seguintes tarefas:
#     </p>
#     <ul>
#         <li>Automatizar o pipeline de (re)treino do modelo</li>
#         <li>Implementar um processo de CI/CD para promover nosso modelo para o ambiente de produção</li>
#         <li>Implementar nossa própria API para servir o modelo</li>
#         <li>Analisar o model drift</li>
#     </ul>
#     <p>
#        Vamos em frente para a parte final do curso 🚀
#     </p>
# </div>

# %% [markdown]
# <div class="custom-slide">
# <h1>Discutindo sobre alta escalabilidade</h1>
#     <img src="images/mlflow-local-serving.png" alt="Sample Image" style="width:100%;border-radius:10px;">
#     <span class="image-ref">Source: https://mlflow.org/docs/latest/deployment/deploy-model-locally.html</span>
# </div>

# %% [markdown]
# <div class="custom-slide">
#     <h1>Arquitetura de referência</h1>
#     <img src="images/mlflow-prod-deployment.png" alt="Sample Image" style="width:100%;border-radius:10px;">
#     <span class="image-ref">Source: https://mlflow.org/docs/latest/deployment/index.html#id1</span>
# </div>
